# %%
#!pip3 install boto3
#!pip3 install s3fs
#!pip install boto3 --upgrade
#!pip install botocore --upgrade
#!pip install s3fs --upgrade

# %% [markdown]
# ##### Importamos la librería que necesitamos para conectarnos a S3

# %%
import boto3

# %% [markdown]
# ##### Para poder conectarnos a nuestra cuenta de AWS tenemos que coger las **credenciales** que se nos facilitan cuando iniciamos nuestra cuenta (`Start Lab`). Una vez inicializada nuestra cuenta, en la pestaña `AWS Details` podremos encontrar la credenciales que necesitamos. Copialas en las siguientes variables:

# %%
aws_access_key_id="ASIAYIR7Z4S3XVTHT2YT"
aws_secret_access_key="9piAhNffbtMroVNAZhhriFw9ynXIZSXgvKm+SJl+"
aws_session_token=""

# %% [markdown]
# ##### Para concectarnos con nuestra cuenta tendemos que definir una `Session` utilizando las credenciales que nos proporcionan, además de establecer la región a la que nos queremos concectar. Por defecto, cuando estemos utilizando **_AWS Academy_ solo podremos utilizar la región de _Northern Virginia_** que tiene este código `us-east-1`.

# %%
session = boto3.session.Session(
 region_name="us-east-1",
 aws_access_key_id=aws_access_key_id,
 aws_secret_access_key=aws_secret_access_key,
 aws_session_token=aws_session_token
)

# %%
s3 = session.client('s3')

# %%
#response = s3.list_buckets()
#response

# %%
BUCKET_NAME = 'marcial-tmf-oct22-msf-data'

# %%
#s3.list_objects(Bucket=BUCKET_NAME)

# %%
#s3.download_file(Bucket=BUCKET_NAME, Key='z_output/m2_features/m2_features.parquet', Filename='data/m2_features.parquet')

# %%
import pandas as pd

# %%
df_msf_id = pd.read_csv('data/task_merge_id_date.csv.gz', compression='gzip')
df_msf_id.head(3)
# Out:
#                 whoid activitydate  msf_seniority__c  gender__c  \
# 0  0033Y00002uNQJvQAO   2023-01-04              22.0          0
# 1  0033Y00002uNQJvQAO   2022-12-16              22.0          0
# 2  0033Y00002uNQJvQAO   2022-10-18              22.0          0
#
#    msf_ltvcont__c  msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 0         4064.87                               4.0                       556
# 1         4064.87                               4.0                       556
# 2         4064.87                               4.0                       556
#
#    npo02__totaloppamount__c  msf_valuetotalcont__c  msf_valuetotaldesc__c  \
# 0                   4064.87                  528.0                      4
# 1                   4064.87                  528.0                      4
# 2                   4064.87                  528.0                      4
#
#    msf_channel__c  days_elapsed_since_previous_modification  msf_newamount__c  \
# 0               2                                      19.0              44.0
# 1               1                                      59.0              44.0
# 2               1                                     659.0              44.0
#
#    msf_newannualizedquota__c  msf_newrecurringperiod__c msf_closetype__c
# 0                      528.0                          1         Negativo
# 1                      528.0                          1         Negativo
# 2                      528.0                          1         Negativo

# %% [markdown]
# ##### Eliminamos columnas duplicadas

# %%
df_msf_id.drop(columns=['npo02__totaloppamount__c', 'msf_valuetotaldesc__c'], inplace=True)

# %%
df_msf = pd.read_csv('data/task_merge_clean.csv.gz', compression='gzip')
df_msf.head(3)
# Out:
#    msf_seniority__c  gender__c  msf_ltvcont__c  \
# 0              22.0          0         4064.87
# 1              22.0          0         4064.87
# 2              22.0          0         4064.87
#
#    msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 0                               4.0                       556
# 1                               4.0                       556
# 2                               4.0                       556
#
#    npo02__totaloppamount__c  msf_valuetotalcont__c  msf_valuetotaldesc__c  \
# 0                   4064.87                  528.0                      4
# 1                   4064.87                  528.0                      4
# 2                   4064.87                  528.0                      4
#
#    msf_channel__c  days_elapsed_since_previous_modification  msf_newamount__c  \
# 0               2                                      19.0              44.0
# 1               1                                      59.0              44.0
# 2               1                                     659.0              44.0
#
#    msf_newannualizedquota__c  msf_newrecurringperiod__c msf_closetype__c
# 0                      528.0                          1         Negativo
# 1                      528.0                          1         Negativo
# 2                      528.0                          1         Negativo

# %% [markdown]
# ##### Eliminamos columnas duplicadas

# %%
df_msf.drop(columns=['npo02__totaloppamount__c', 'msf_valuetotaldesc__c'], inplace=True)

# %% [markdown]
# ##### Comprobamos nulos

# %%
print(df_msf.isna().sum())
# Out:
# msf_seniority__c                                0
# gender__c                                       0
# msf_ltvcont__c                                  0
# msf_recencyrecurringdonorcont__c                0
# msf_rfvrecurringdonor__c                        0
# msf_valuetotalcont__c                           0
# msf_channel__c                                  0
# days_elapsed_since_previous_modification      353
# msf_newamount__c                                0
# msf_newannualizedquota__c                       0
# msf_newrecurringperiod__c                       0
# msf_closetype__c                            21531
# dtype: int64

# %% [markdown]
# ##### Vemos si el fichero está balanceado en cuanto a la variable objetivo

# %%
df_msf.dropna(subset=['days_elapsed_since_previous_modification'], inplace=True)
df_msf.dropna(subset=['msf_closetype__c'], inplace=True)
df_msf['msf_closetype__c'] = df_msf['msf_closetype__c'].replace({'Negativo': 0, 'Positivo': 1})
print(df_msf['msf_closetype__c'].value_counts())
# Out:
# 0    709109
# 1    393982
# Name: msf_closetype__c, dtype: int64

# %% [markdown]
# ##### Comprobamos que no es el caso por lo que procedemos a balancear los registros

# %%
from sklearn.utils import resample

negative = df_msf[df_msf["msf_closetype__c"] == 0]
positive = df_msf[df_msf["msf_closetype__c"] == 1]
print(negative.shape)
print(positive.shape)

negative_downsampled = resample(negative,
             replace=True,
             n_samples=len(positive),
             random_state=42)

print(negative_downsampled.shape)

# Combine the two classes
df_msf_balanced = pd.concat([negative_downsampled, positive])

print(df_msf_balanced["msf_closetype__c"].value_counts())
# Out:
# (709109, 12)
# (393982, 12)
# (393982, 12)
# 0    393982
# 1    393982
# Name: msf_closetype__c, dtype: int64

# %% [markdown]
# ##### Importamos Tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# ##### Separamos las columnas predictoras y la columna a predecir (objetivo)

# %%
x = df_msf_balanced.drop(columns=["msf_closetype__c"])
y = df_msf_balanced.msf_closetype__c

# %% [markdown]
# ##### Normalizamos los valores

# %%
from sklearn.preprocessing import MinMaxScaler
#cols_to_scale = ["msf_seniority__c","msf_ltvcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c","days_elapsed_since_previous_modification","msf_newamount__c","msf_newannualizedquota__c"]
#cols_to_scale = ["msf_ltvcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c"]
cols_to_scale = ["msf_seniority__c","msf_ltvcont__c","msf_recencyrecurringdonorcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c","msf_channel__c","days_elapsed_since_previous_modification","msf_newamount__c","msf_newannualizedquota__c","msf_newrecurringperiod__c"]
scaler = MinMaxScaler()
x[cols_to_scale] = scaler.fit_transform(x[cols_to_scale])
x.head(3)
# Out:
#          msf_seniority__c  gender__c  msf_ltvcont__c  \
# 193757           0.138889          0        0.013239
# 1064766          0.194444          0        0.009633
# 209491           0.527778          0        0.020818
# 580549           0.083333          0        0.002530
# 411613           0.250000          0        0.004796
#
#          msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 193757                                0.0                  0.986111
# 1064766                               0.0                  0.986111
# 209491                                0.0                  0.986111
# 580549                                0.0                  0.939815
# 411613                                0.0                  0.972222
#
#          msf_valuetotalcont__c  msf_channel__c  \
# 193757                0.011181             0.2
# 1064766               0.016842             0.0
# 209491                0.021560             0.0
# 580549                0.008350             0.0
# 411613                0.003868             0.0
#
#          days_elapsed_since_previous_modification  msf_newamount__c  \
# 193757                                   0.496104          0.003040
# 1064766                                  0.500796          0.002080
# 209491                                   0.499650          0.003841
# 580549                                   0.499843          0.001440
# 411613                                   0.499083          0.000960
#
#          msf_newannualizedquota__c  msf_newrecurringperiod__c
# 193757                    0.009481                        0.0
# 1064766                   0.006601                        0.0
# 209491                    0.011881                        0.0
# 580549                    0.004681                        0.0
# 411613                    0.003240                        0.0

# %% [markdown]
# ##### Separamos los datos en un conjunto de train y en un conjunto de test (25% de los datos)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=0)

# %%
x_train.head(3)
# Out:
#          msf_seniority__c  gender__c  msf_ltvcont__c  \
# 1005667          0.194444          1        0.011335
# 401689           0.777778          0        0.026212
# 111123           0.111111          0        0.005039
#
#          msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 1005667                               4.0                  0.981481
# 401689                                4.0                  0.986111
# 111123                                4.0                  0.939815
#
#          msf_valuetotalcont__c  msf_channel__c  \
# 1005667               0.005520               1
# 401689                0.014011               1
# 111123                0.009482               1
#
#          days_elapsed_since_previous_modification  msf_newamount__c  \
# 1005667                                  0.496200          0.004961
# 401689                                   0.499916          0.003361
# 111123                                   0.500012          0.002560
#
#          msf_newannualizedquota__c  msf_newrecurringperiod__c
# 1005667                   0.015242                          1
# 401689                    0.010441                          1
# 111123                    0.008041                          1

# %% [markdown]
# ## MLOps
# ![](images/mlflow-training.png)

# %% [markdown]
# ##### Importamos MLFlow y creamos un grupo de experimentos

# %%
import mlflow
mlflow.set_tracking_uri('http://localhost:5000')

# %%
experiment = mlflow.create_experiment("msf-quote")

# %%
experiment = mlflow.get_experiment_by_name("msf-quote")
experiment
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/469179163190949195', creation_time=1696758244744, experiment_id='469179163190949195', last_update_time=1696758244744, lifecycle_stage='active', name='msf-quote', tags={}>

# %% [markdown]
# ##### DNN model con Tensorflow

# %% [markdown]
# ##### Registrándo todo en MLFlow creamos un modelo DNN con un clasificador binario que nos devuelva un valor con la probabilidad de aumentar la cuota

# %%
import time
import pydot 
import graphviz

with mlflow.start_run(experiment_id=experiment.experiment_id, run_name="msf-quote-increase-raw") as run:
    
    epochs=100
    learning_rate=0.01
    n_layers = 5
    nodes = [32, 64, 32, 16, 8]
    optimizer = 'adam'
    loss = 'binary_crossentropy'
    
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='accuracy', min_delta=0.0001, patience=8, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, min_lr=0.00001)
    
    # Registramos los parámetros
    mlflow.log_param('epochs', epochs)
    mlflow.log_param('n_layers', n_layers)
    mlflow.log_param('nodes', nodes)
    mlflow.log_param('optimizer', optimizer)
    mlflow.log_param('loss', loss)
   
    dense_layers = [tf.keras.layers.Dense(nodes[i], activation='relu') for i in range(n_layers)]
    
    model = tf.keras.models.Sequential(dense_layers)
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    plot_model(model, to_file='images/dnn_model.png', show_shapes=True, show_layer_names=True)
   
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

    start_time = time.time()
    hist = model.fit(x=x_train, y=y_train, epochs=epochs, callbacks=[early_stop, reduce_lr], validation_data=(x_test, y_test))
    train_time = time.time() - start_time
    
    _, train_accuracy, train_precision, train_recall = model.evaluate(x_train, y_train)
    _, test_accuracy, test_precision, test_recall = model.evaluate(x_test, y_test)

    # Registramos las métricas y el learning rate final
    mlflow.log_metric('train_time', train_time)
    mlflow.log_metric('train_accuracy', train_accuracy)
    mlflow.log_metric('train_precision', train_precision)
    mlflow.log_metric('train_recall', train_recall)
    mlflow.log_metric('test_accuracy', test_accuracy)
    mlflow.log_metric('test_precision', test_precision)
    mlflow.log_metric('test_recall', test_recall)
    final_lr = float(model.optimizer.lr.numpy())
    mlflow.log_param('final_learning_rate', final_lr)    
    
    # Registramos el modelo
    mlflow.tensorflow.log_model(model, 'msf-quote-increase-dnn-raw')
    #mlflow.tensorflow.log_model(model, 'heart-model-tf', registered_model_name="heart-model-tf")
# Out:
# Epoch 1/100
# 16006/16006 [==============================] - 25s 1ms/step - loss: 0.6792 - accuracy: 0.5499 - precision_16: 0.5453 - recall_16: 0.6009 - val_loss: 0.6740 - val_accuracy: 0.5582 - val_precision_16: 0.5690 - val_recall_16: 0.4804 - lr: 0.0010
# Epoch 2/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6730 - accuracy: 0.5641 - precision_16: 0.5568 - recall_16: 0.6281 - val_loss: 0.6760 - val_accuracy: 0.5542 - val_precision_16: 0.5336 - val_recall_16: 0.8599 - lr: 0.0010
# Epoch 3/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6719 - accuracy: 0.5664 - precision_16: 0.5584 - recall_16: 0.6351 - val_loss: 0.6706 - val_accuracy: 0.5694 - val_precision_16: 0.5618 - val_recall_16: 0.6306 - lr: 0.0010
# Epoch 4/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6710 - accuracy: 0.5690 - precision_16: 0.5607 - recall_16: 0.6373 - val_loss: 0.6697 - val_accuracy: 0.5719 - val_precision_16: 0.5615 - val_recall_16: 0.6570 - lr: 0.0010
# Epoch 5/100
# 16006/16006 [==============================] - 24s 2ms/step - loss: 0.6703 - accuracy: 0.5717 - precision_16: 0.5639 - recall_16: 0.6325 - val_loss: 0.6691 - val_accuracy: 0.5730 - val_precision_16: 0.5708 - val_recall_16: 0.5888 - lr: 0.0010
# Epoch 6/100
# 16006/16006 [==============================] - 26s 2ms/step - loss: 0.6695 - accuracy: 0.5733 - precision_16: 0.5656 - recall_16: 0.6322 - val_loss: 0.6686 - val_accuracy: 0.5714 - val_precision_16: 0.5805 - val_recall_16: 0.5150 - lr: 0.0010
# Epoch 7/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6686 - accuracy: 0.5757 - precision_16: 0.5688 - recall_16: 0.6252 - val_loss: 0.6677 - val_accuracy: 0.5756 - val_precision_16: 0.5787 - val_recall_16: 0.5554 - lr: 0.0010
# Epoch 8/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6677 - accuracy: 0.5772 - precision_16: 0.5699 - recall_16: 0.6299 - val_loss: 0.6664 - val_accuracy: 0.5809 - val_precision_16: 0.5703 - val_recall_16: 0.6566 - lr: 0.0010
# Epoch 9/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.
100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6535 - accuracy: 0.6047 - precision_16: 0.5984 - recall_16: 0.6365 - val_loss: 0.6547 - val_accuracy: 0.6032 - val_precision_16: 0.5936 - val_recall_16: 0.6541 - lr: 1.0000e-05
# Epoch 60/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6535 - accuracy: 0.6047 - precision_16: 0.5985 - recall_16: 0.6361 - val_loss: 0.6545 - val_accuracy: 0.6026 - val_precision_16: 0.5995 - val_recall_16: 0.6181 - lr: 1.0000e-05
# Epoch 61/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6535 - accuracy: 0.6046 - precision_16: 0.5983 - recall_16: 0.6369 - val_loss: 0.6544 - val_accuracy: 0.6034 - val_precision_16: 0.5968 - val_recall_16: 0.6375 - lr: 1.0000e-05
# Epoch 62/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6535 - accuracy: 0.6047 - precision_16: 0.5985 - recall_16: 0.6357 - val_loss: 0.6544 - val_accuracy: 0.6036 - val_precision_16: 0.5969 - val_recall_16: 0.6381 - lr: 1.0000e-05
# Epoch 63/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6534 - accuracy: 0.6049 - precision_16: 0.5985 - recall_16: 0.6374 - val_loss: 0.6545 - val_accuracy: 0.6034 - val_precision_16: 0.5939 - val_recall_16: 0.6539 - lr: 1.0000e-05
# Epoch 64/100
# 16006/16006 [==============================] - 24s 1ms/step - loss: 0.6534 - accuracy: 0.6046 - precision_16: 0.5982 - recall_16: 0.6372 - val_loss: 0.6545 - val_accuracy: 0.6032 - val_precision_16: 0.5938 - val_recall_16: 0.6537 - lr: 1.0000e-05
# 16006/16006 [==============================] - 14s 869us/step - loss: 0.6535 - accuracy: 0.6045 - precision_16: 0.5980 - recall_16: 0.6375
# 16006/16006 [==============================] - 14s 871us/step - loss: 0.6535 - accuracy: 0.6045 - precision_16: 0.5980 - recall_16: 0.6375
# 2023/10/08 12:27:54 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: C:\Users\mlala\AppData\Local\Temp\tmpc4xtr14r\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\mlala\AppData\Local\Temp\tmpc4xtr14r\model\data\model\assets

# %% [markdown]
# ##### Representamos en una gráfica la función de pérdida

# %%
# Para mostrar gráficas
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(hist.history['loss'], label="loss")
plt.plot(hist.history['val_loss'], label="val_loss")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()

# %% [markdown]
# ##### Procedemos a regsitrar el experimento en MLFlow y pasarlo a producción si procede

# %%
msf_experiments = mlflow.search_runs(search_all_experiments=True)
msf_experiments
# Out:
#                              run_id       experiment_id    status  \
# 0  09736a66a16a435dbd7718c2b577c220  469179163190949195  FINISHED
# 1  ee8e32b1c96d4c91ad6e787f54ad14cb  469179163190949195    FAILED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/469179163190949195/09736a66a...
# 1  mlflow-artifacts:/469179163190949195/ee8e32b1c...
#
#                         start_time                         end_time  \
# 0 2023-10-08 10:01:25.888000+00:00 2023-10-08 10:28:01.405000+00:00
# 1 2023-10-08 09:44:15.942000+00:00 2023-10-08 09:59:20.109000+00:00
#
#    metrics.train_precision  metrics.test_recall  metrics.train_time  \
# 0                 0.597995             0.637535         1558.661452
# 1                      NaN                  NaN                 NaN
#
#    metrics.test_accuracy  ...  params.epochs  params.final_learning_rate  \
# 0                0.60447  ...            100       9.999999747378752e-06
# 1                    NaN  ...            100                        None
#
#    params.n_layers params.optimizer          params.loss  \
# 0                5             adam  binary_crossentropy
# 1                5             adam  binary_crossentropy
#
#       tags.mlflow.runName                      tags.mlflow.log-model.history  \
# 0  msf-quote-increase-raw  [{"run_id": "09736a66a16a435dbd7718c2b577c220"...
# 1  msf-quote-increase-raw                                               None
#
#   tags.mlflow.user tags.mlflow.source.type  \
# 0            mlala                   LOCAL
# 1            mlala                   LOCAL
#
#                              tags.mlflow.source.name
# 0  C:\Users\mlala\AppData\Local\Programs\Python\P...
# 1  C:\Users\mlala\AppData\Local\Programs\Python\P...
#
# [2 rows x 24 columns]

# %%
msf_experiments.loc[msf_experiments['tags.mlflow.runName'] == 'msf-quote-increase-raw']
# Out:
#                              run_id       experiment_id    status  \
# 0  09736a66a16a435dbd7718c2b577c220  469179163190949195  FINISHED
# 1  ee8e32b1c96d4c91ad6e787f54ad14cb  469179163190949195    FAILED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/469179163190949195/09736a66a...
# 1  mlflow-artifacts:/469179163190949195/ee8e32b1c...
#
#                         start_time                         end_time  \
# 0 2023-10-08 10:01:25.888000+00:00 2023-10-08 10:28:01.405000+00:00
# 1 2023-10-08 09:44:15.942000+00:00 2023-10-08 09:59:20.109000+00:00
#
#    metrics.train_precision  metrics.test_recall  metrics.train_time  \
# 0                 0.597995             0.637535         1558.661452
# 1                      NaN                  NaN                 NaN
#
#    metrics.test_accuracy  ...  params.epochs  params.final_learning_rate  \
# 0                0.60447  ...            100       9.999999747378752e-06
# 1                    NaN  ...            100                        None
#
#    params.n_layers params.optimizer          params.loss  \
# 0                5             adam  binary_crossentropy
# 1                5             adam  binary_crossentropy
#
#       tags.mlflow.runName                      tags.mlflow.log-model.history  \
# 0  msf-quote-increase-raw  [{"run_id": "09736a66a16a435dbd7718c2b577c220"...
# 1  msf-quote-increase-raw                                               None
#
#   tags.mlflow.user tags.mlflow.source.type  \
# 0            mlala                   LOCAL
# 1            mlala                   LOCAL
#
#                              tags.mlflow.source.name
# 0  C:\Users\mlala\AppData\Local\Programs\Python\P...
# 1  C:\Users\mlala\AppData\Local\Programs\Python\P...
#
# [2 rows x 24 columns]

# %%
model_uri = f"runs:/09736a66a16a435dbd7718c2b577c220/msf-quote-increase-raw"
model_uri
# Out:
# 'runs:/09736a66a16a435dbd7718c2b577c220/msf-quote-increase-raw'

# %%
model_version = mlflow.register_model(
    model_uri,
    "msf-quote-increase-raw"
)
# Out:
# Successfully registered model 'msf-quote-increase-raw'.
# 2023/10/08 12:28:53 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: msf-quote-increase-raw, version 1
# Created version '1' of model 'msf-quote-increase-raw'.

# %%
client = mlflow.tracking.MlflowClient()
model_prod = client.transition_model_version_stage(
    name='msf-quote-increase-raw',
    version=1,
    stage="Production",
)

# %% [markdown]
# ##### Leemos el fichero de features

# %%
df_msf_feature_store = pd.read_csv('data/feature_store.csv.gz', compression='gzip')
df_msf_feature_store
# Out:
#                      whoid activitydate  msf_seniority__c  gender__c  \
# 0       0033Y00002uNQJvQAO   2023-01-04              22.0          0
# 1       0033Y00002uNQMaQAO   2022-12-28              20.0          0
# 2       0033Y00002uNQSMQA4   2022-10-20              22.0          1
# 3       0033Y00002uNQU0QAO   2022-11-15              21.0          0
# 4       0033Y00002uNQUUQA4   2023-02-09              20.0          0
# ...                    ...          ...               ...        ...
# 182933  0033Y00003TU66vQAD   2023-05-30               1.0          0
# 182934  0033Y00003TUb7fQAD   2023-06-12               1.0          1
# 182935  0033Y00003TUwXXQA1   2023-06-07               1.0          0
# 182936  0033Y00003Up91NQAR   2023-06-16               1.0          0
# 182937  0033Y00003VXhwyQAD   2023-06-14               1.0          1
#
#         msf_ltvcont__c  msf_recencyrecurringdonorcont__c  \
# 0              4064.87                               4.0
# 1              2040.00                               4.0
# 2               961.10                             277.0
# 3              4788.00                               4.0
# 4              5159.00                               4.0
# ...                ...                               ...
# 182933          360.00                               4.0
# 182934           93.00                               4.0
# 182935          159.00                               4.0
# 182936           67.00                               4.0
# 182937          265.00                               4.0
#
#         msf_rfvrecurringdonor__c  npo02__totaloppamount__c  \
# 0                            556                   4064.87
# 1                            544                   2040.00
# 2                            552                    961.10
# 3                            555                   4788.00
# 4                            555                   5159.00
# ...                          ...                       ...
# 182933                       505                    360.00
# 182934                       503                     93.00
# 182935                       505                    159.00
# 182936                       502                     67.00
# 182937                       505                    265.00
#
#         msf_valuetotalcont__c  msf_valuetotaldesc__c  msf_channel__c  \
# 0                       528.0                      4               2
# 1                       140.0                      2               1
# 2                        55.0                      1               1
# 3                       332.0                      3               1
# 4                       364.0                      3               1
# ...                       ...                    ...             ...
# 182933                  420.0                      3               1
# 182934                  108.0                      1               1
# 182935                  180.0                      3               1
# 182936                   84.0                      1               1
# 182937                  300.0                      3               1
#
#         days_elapsed_since_previous_modification  msf_newamount__c  \
# 0                                           19.0              44.0
# 1                                          350.0              10.0
# 2                                          465.0              55.0
# 3                                          372.0              26.0
# 4                                          449.0              22.0
# ...                                          ...               ...
# 182933                                       4.0              35.0
# 182934                                      17.0               9.0
# 182935                                      12.0              15.0
# 182936                                      21.0               7.0
# 182937                                      19.0              25.0
#
#         msf_newannualizedquota__c  msf_newrecurringperiod__c msf_closetype__c
# 0                           528.0                          1         Negativo
# 1                           120.0                          1         Positivo
# 2                            55.0                          5         Positivo
# 3                           312.0                          1         Positivo
# 4                           264.0                          1         Positivo
# ...                           ...                        ...              ...
# 182933                      420.0                          1         Positivo
# 182934                      108.0                          1         Positivo
# 182935                      180.0                          1         Positivo
# 182936                       84.0                          1         Positivo
# 182937                      300.0                          1         Positivo
#
# [182938 rows x 16 columns]

# %% [markdown]
# ##### Eliminamos columnas que no necesitamos y la variable objetivo

# %%
df_msf_feature_store.drop(columns=['activitydate','npo02__totaloppamount__c', 'msf_valuetotaldesc__c','msf_closetype__c'], inplace=True)

# %% [markdown]
# ##### Eliminaos regsitros con nulos en la columna days_elapsed_since_previous_modification

# %%
df_msf_feature_store.dropna(subset=['days_elapsed_since_previous_modification'], inplace=True)

# %%
df_msf_feature_store_no_id = df_msf_feature_store.copy()

# %% [markdown]
# ##### Guardamos un fichero equivalente pero sin el id de socio

# %%
df_msf_feature_store_no_id = df_msf_feature_store.dropna(subset=['whoid'])

# %%
df_msf_feature_store_no_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182868 entries, 0 to 182937
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   whoid                                     182868 non-null  object
#  1   msf_seniority__c                          182868 non-null  float64
#  2   gender__c                                 182868 non-null  int64
#  3   msf_ltvcont__c                            182868 non-null  float64
#  4   msf_recencyrecurringdonorcont__c          182868 non-null  float64
#  5   msf_rfvrecurringdonor__c                  182868 non-null  int64
#  6   msf_valuetotalcont__c                     182868 non-null  float64
#  7   msf_channel__c                            182868 non-null  int64
#  8   days_elapsed_since_previous_modification  182868 non-null  float64
#  9   msf_newamount__c                          182868 non-null  float64
#  10  msf_newannualizedquota__c                 182868 non-null  float64
#  11  msf_newrecurringperiod__c                 182868 non-null  int64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 18.1+ MB

# %%
df_msf_feature_store_no_id = df_msf_feature_store.drop(columns=["whoid"])

# %%
df_msf_feature_store_no_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182868 entries, 0 to 182937
# Data columns (total 11 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   msf_seniority__c                          182868 non-null  float64
#  1   gender__c                                 182868 non-null  int64
#  2   msf_ltvcont__c                            182868 non-null  float64
#  3   msf_recencyrecurringdonorcont__c          182868 non-null  float64
#  4   msf_rfvrecurringdonor__c                  182868 non-null  int64
#  5   msf_valuetotalcont__c                     182868 non-null  float64
#  6   msf_channel__c                            182868 non-null  int64
#  7   days_elapsed_since_previous_modification  182868 non-null  float64
#  8   msf_newamount__c                          182868 non-null  float64
#  9   msf_newannualizedquota__c                 182868 non-null  float64
#  10  msf_newrecurringperiod__c                 182868 non-null  int64
# dtypes: float64(7), int64(4)
# memory usage: 16.7 MB

# %%
##### Normalizamos las features

# %%
from sklearn.preprocessing import MinMaxScaler
#cols_to_scale = ["msf_seniority__c","msf_ltvcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c","days_elapsed_since_previous_modification","msf_newamount__c","msf_newannualizedquota__c"]
#cols_to_scale = ["msf_ltvcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c"]
cols_to_scale = ["msf_seniority__c","msf_ltvcont__c","msf_recencyrecurringdonorcont__c","msf_rfvrecurringdonor__c","msf_valuetotalcont__c","msf_channel__c","days_elapsed_since_previous_modification","msf_newamount__c","msf_newannualizedquota__c","msf_newrecurringperiod__c"]
scaler = MinMaxScaler()
df_msf_feature_store_no_id[cols_to_scale] = scaler.fit_transform(df_msf_feature_store_no_id[cols_to_scale])
df_msf_feature_store_no_id.head(3)
# Out:
#    msf_seniority__c  gender__c  msf_ltvcont__c  \
# 0          0.583333          0        0.020947
# 1          0.527778          0        0.010471
# 2          0.583333          1        0.004890
#
#    msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 0                          0.000000                  0.991870
# 1                          0.000000                  0.943089
# 2                          0.280864                  0.975610
#
#    msf_valuetotalcont__c  msf_channel__c  \
# 0               0.024768             1.0
# 1               0.006463             0.0
# 2               0.002453             0.0
#
#    days_elapsed_since_previous_modification  msf_newamount__c  \
# 0                                  0.006614          0.006881
# 1                                  0.036199          0.001440
# 2                                  0.046478          0.008641
#
#    msf_newannualizedquota__c  msf_newrecurringperiod__c
# 0                   0.021003                        0.0
# 1                   0.004681                        0.0
# 2                   0.002080                        1.0

# %% [markdown]
# ##### Hacemos las predicciones para cada una de los registros

# %%
predictions = model.predict(df_msf_feature_store_no_id)
# Out:
# 5715/5715 [==============================] - 4s 693us/step

# %%
# Añadimos las prediciones al dataframe con los ids de socios

# %%
df_msf_feature_store['prediction'] = predictions

# %%
df_msf_feature_store
# Out:
#                      whoid  msf_seniority__c  gender__c  msf_ltvcont__c  \
# 0       0033Y00002uNQJvQAO              22.0          0         4064.87
# 1       0033Y00002uNQMaQAO              20.0          0         2040.00
# 2       0033Y00002uNQSMQA4              22.0          1          961.10
# 3       0033Y00002uNQU0QAO              21.0          0         4788.00
# 4       0033Y00002uNQUUQA4              20.0          0         5159.00
# ...                    ...               ...        ...             ...
# 182933  0033Y00003TU66vQAD               1.0          0          360.00
# 182934  0033Y00003TUb7fQAD               1.0          1           93.00
# 182935  0033Y00003TUwXXQA1               1.0          0          159.00
# 182936  0033Y00003Up91NQAR               1.0          0           67.00
# 182937  0033Y00003VXhwyQAD               1.0          1          265.00
#
#         msf_recencyrecurringdonorcont__c  msf_rfvrecurringdonor__c  \
# 0                                    4.0                       556
# 1                                    4.0                       544
# 2                                  277.0                       552
# 3                                    4.0                       555
# 4                                    4.0                       555
# ...                                  ...                       ...
# 182933                               4.0                       505
# 182934                               4.0                       503
# 182935                               4.0                       505
# 182936                               4.0                       502
# 182937                               4.0                       505
#
#         msf_valuetotalcont__c  msf_channel__c  \
# 0                       528.0               2
# 1                       140.0               1
# 2                        55.0               1
# 3                       332.0               1
# 4                       364.0               1
# ...                       ...             ...
# 182933                  420.0               1
# 182934                  108.0               1
# 182935                  180.0               1
# 182936                   84.0               1
# 182937                  300.0               1
#
#         days_elapsed_since_previous_modification  msf_newamount__c  \
# 0                                           19.0              44.0
# 1                                          350.0              10.0
# 2                                          465.0              55.0
# 3                                          372.0              26.0
# 4                                          449.0              22.0
# ...                                          ...               ...
# 182933                                       4.0              35.0
# 182934                                      17.0               9.0
# 182935                                      12.0              15.0
# 182936                                      21.0               7.0
# 182937                                      19.0              25.0
#
#         msf_newannualizedquota__c  msf_newrecurringperiod__c  prediction
# 0                           528.0                          1    0.171073
# 1                           120.0                          1    0.281458
# 2                            55.0                          5    0.335936
# 3                           312.0                          1    0.458535
# 4                           264.0                          1    0.424301
# ...                           ...                        ...         ...
# 182933                      420.0                          1    0.493076
# 182934                      108.0                          1    0.276711
# 182935                      180.0                          1    0.371433
# 182936                       84.0                          1    0.298411
# 182937                      300.0                          1    0.420553
#
# [182868 rows x 13 columns]

# %%
df_msf_feature_store.to_csv('data/feature_store_with_predictions.csv')

# %% [markdown]
# ##### Nos quedamos en un dataframe el id del socio con su correspondiente predicción

# %%
df_msf_id_predictions = df_msf_feature_store[['whoid', 'prediction']]
df_msf_id_predictions
# Out:
#                      whoid  prediction
# 0       0033Y00002uNQJvQAO    0.171073
# 1       0033Y00002uNQMaQAO    0.281458
# 2       0033Y00002uNQSMQA4    0.335936
# 3       0033Y00002uNQU0QAO    0.458535
# 4       0033Y00002uNQUUQA4    0.424301
# ...                    ...         ...
# 182933  0033Y00003TU66vQAD    0.493076
# 182934  0033Y00003TUb7fQAD    0.276711
# 182935  0033Y00003TUwXXQA1    0.371433
# 182936  0033Y00003Up91NQAR    0.298411
# 182937  0033Y00003VXhwyQAD    0.420553
#
# [182868 rows x 2 columns]
